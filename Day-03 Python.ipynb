# %%
INTRODUCTION TO F STRING:

# %%
#General syntax of f strings:

# %%
f"custom message{place_holder_1}  {place_holder_2}........{place_holder_2}

# %%
firstname="David"
lastname="John"

# %%
#adding whitespaces to strings :

# %%
#req :i want to get the full name...?

# %%
fullname=f"{firstname} {lastname}"
print(fullname)
# Out:
# David John

# %%
message=f"Keep up the good work,{fullname}"
print(message)
# Out:
# Keep up the good work,David John

# %%
print("fav_Programminh_lang:pythonc++javajavascriptswift")
# Out:
# fav_Programminh_lang:pythonc++javajavascriptswift

# %%
#\n --> new line delimiter

# %%
print("fav_Programminh_lang:\npython\nc++\njava\njavascript\nswift")
# Out:
# fav_Programminh_lang:
# python
# c++
# java
# javascript
# swift

# %%
#\t---> tab delimiter

# %%
print("fav_Programminh_lang:\n\tpython\n\tc++\n\tjava\n\tjavascript\n\tswift")
# Out:
# fav_Programminh_lang:
# 	python
# 	c++
# 	java
# 	javascript
# 	swift

# %%
Removing whitespaces from the strings :

# %%
name=' python'
print(name)
# Out:
#  python

# %%
name2='python'
print(name2)
# Out:
# python

# %%
name3='python '
print(name3)
# Out:
# python

# %%
name.lstrip()# left strip
# Out:
# 'python'

# %%
name3.rstrip()# right strip
# Out:
# 'python'

# %%
name4=" python "
print(name4)
# Out:
#  python

# %%
name4.strip()
# Out:
# 'python'
